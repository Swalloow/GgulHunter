# %%
import numpy as np
import pandas as pd

# %%
val = train.head(1).values

# %%
val
# Out:
# array([['2014년 08월 07일(목)', 1, '명량', datetime.datetime(2014, 7, 30, 0, 0),
#         4892511700, 0.595, -380933700, -0.1, 61033902816, 652776, -50111,
#         -0.1, 7982455, 1239, 6776, '한국', '한국', '(주)빅스톤픽쳐스', '씨제이이앤엠(주)',
#         '15세이상관람가', '사극,액션', '김한민',
#         '최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,김태훈,이승준,오타니 료헤이,박보검,박원우,서광,오명훈,유명환,윤희경,이윤기,정수남,정순태,정의석,김원해,이해영,장준녕,김길동,김강일,강태영,하형원,한상대,김동원,김민석,김민식,김재철,김준형,김현중,박선용,박노식,최덕문,조복래,문영동']], dtype=object)

# %%
train.loc[lambda train: train['영화명'] == '명량', :]
# Out:
#                    날짜   순위 영화명                  개봉일          매출액 매출액 점유율  \
# 4    2014년 08월 07일(목)    1  명량  2014-07-30 00:00:00   4892511700   0.595
# 76   2014년 08월 06일(수)    1  명량  2014-07-30 00:00:00   5273445400   0.609
# 158  2014년 08월 05일(화)    1  명량  2014-07-30 00:00:00   6511760400   0.731
# 241  2014년 08월 04일(월)    1  명량  2014-07-30 00:00:00   7455501400   0.731
# 311  2014년 08월 03일(일)    1  명량  2014-07-30 00:00:00  10031212500   0.675
# 380  2014년 08월 02일(토)    1  명량  2014-07-30 00:00:00   9826541209   0.651
# 452  2014년 08월 01일(금)    1  명량  2014-07-30 00:00:00   6918410307    0.64
# 4    2014년 08월 14일(목)    1  명량  2014-07-30 00:00:00   3209749900   0.424
# 93   2014년 08월 13일(수)    1  명량  2014-07-30 00:00:00   2739598400   0.416
# 182  2014년 08월 12일(화)    1  명량  2014-07-30 00:00:00   3287901500   0.527
# 260  2014년 08월 11일(월)    1  명량  2014-07-30 00:00:00   3924891200   0.576
# 324  2014년 08월 10일(일)    1  명량  2014-07-30 00:00:00   8225301600   0.584
# ...

# %%
train.columns
# Out:
# Index(['날짜', '순위', '영화명', '개봉일', '매출액', '매출액 점유율', '매출액증감 (전일대비)',
#        '매출액증감율 (전일대비)', '누적매출액', '관객수', '관객수증감 (전일대비)', '관객수증감율 (전일대비)',
#        '누적관객수', '스크린수', '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독',
#        '배우'],
#       dtype='object')

# %%
import datetime

# %%
test_df = pd.DataFrame([['2016년 09월 30일(금)', 
'고산자, 대동여지도',
datetime.datetime(2016, 9, 7, 0, 0),
'한국', 
'한국',
'(주)시네마서비스',
'씨제이이앤엠(주)',
'전체관람가',
'사극',
'강우석',
'차승원,유준상,김인권,남지현,신동미,남경읍,태인호,공형진,김종수'], ['2016년 09월 30일(금)', 
'매그니피센트 7',
datetime.datetime(2016, 9, 14, 0, 0),
'미국', 
'미국',
'',
'유니버설픽쳐스인터내셔널 코리아(유)',
'15세이상관람가',
'액션, 서부극(웨스턴)',
'안톤 후쿠아',
'덴젤 워싱턴,크리스 프랫,이병헌,에단 호크,맷 보머,빈센트 도노프리오,해일리 베넷,캠 지갠뎃' ],
                        
['2016년 09월 30일(금)', 
'카페 소사이어티',
datetime.datetime(2016, 9, 14, 0, 0),
'미국', 
'미국',
'',
'CGV아트하우스',
'전체관람가',
'멜로/로맨스, 드라마',
'우디 앨런',
'제시 아이젠버그, 크리스틴 스튜어트, 스티브 카렐, 블레이크 라이블리' ]
                        
                       ], columns=['날짜', '영화명', '개봉일', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독',
       '배우'])

# %%
test_df
# Out:
#                  날짜         영화명        개봉일 대표국적  국적        제작사  \
# 0  2016년 09월 30일(금)  고산자, 대동여지도 2016-09-07   한국  한국  (주)시네마서비스
# 1  2016년 09월 30일(금)    매그니피센트 7 2016-09-14   미국  미국
# 2  2016년 09월 30일(금)    카페 소사이어티 2016-09-14   미국  미국
#
#                    배급사        등급            장르      감독  \
# 0            씨제이이앤엠(주)     전체관람가            사극     강우석
# 1  유니버설픽쳐스인터내셔널 코리아(유)  15세이상관람가  액션, 서부극(웨스턴)  안톤 후쿠아
# 2             CGV아트하우스     전체관람가   멜로/로맨스, 드라마   우디 앨런
#
#                                                   배우
# 0                차승원,유준상,김인권,남지현,신동미,남경읍,태인호,공형진,김종수
# 1  덴젤 워싱턴,크리스 프랫,이병헌,에단 호크,맷 보머,빈센트 도노프리오,해일리 베넷,...
# 2             제시 아이젠버그, 크리스틴 스튜어트, 스티브 카렐, 블레이크 라이블리

# %%
test_df.to_pickle('test.p')
