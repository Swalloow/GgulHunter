# %% [markdown]
# # Preprocessing csv files

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
filename = "14.08.01-08.07.xlsx.xlsx"
new_filename = "a-14.08.01-08.07.csv"

# %%
train = pd.read_excel("futures_data/" + filename)
train.head()
# Out:
#   2014년 08월 07일(목) Unnamed: 1           Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0              NaN        NaN                  NaN         NaN        NaN
# 1  일별 박스오피스 검색 리스트        NaN                  NaN         NaN        NaN
# 2               순위        영화명                  개봉일        매출액         매출액
# 3              NaN        NaN                  NaN         NaN       점유율
# 4                1         명량  2014-07-30 00:00:00  4892511700      0.595
#
#    Unnamed: 5 Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0         NaN        NaN          NaN        NaN        NaN
# 1         NaN        NaN          NaN        NaN        NaN
# 2       매출액증감     매출액증감율       누적매출액        관객수       관객수증감
# 3     (전일대비)     (전일대비)           NaN        NaN    (전일대비)
# 4  -380933700       -0.1  61033902816     652776     -50111
#
#                          ...                         Unnamed: 12 Unnamed: 13  \
# 0                        ...                                 NaN         NaN
# 1                        ...                                 NaN         NaN
# 2                        ...                               스크린수        상영횟수
# 3                        ...                                 NaN         NaN
# 4                        ...                                1239        6776
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       대표국적          국적         제작사         배급사          등급          장르
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4          한국          한국   (주)빅스톤픽쳐스   씨제이이앤엠(주)    15세이상관람가       사극,액션
#
#   Unnamed: 20                                        Unnamed: 21
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         감독                                                 배우
# 3         NaN                                                NaN
# 4         김한민  최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,김태훈,이승준,오타니 료헤이,...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Preprocessing Excel files

# %%
new_colums = ['순위',
              '영화명',
              '개봉일',
              '매출액',
              '매출액 점유율',
              '매출액증감 (전일대비)',
              '매출액증감율 (전일대비)',
              '누적매출액',
              '관객수',
              '관객수증감 (전일대비)',
              '관객수증감율 (전일대비)',
              '누적관객수',
              '스크린수',
              '상영횟수',
              '대표국적',
              '국적',
              '제작사',
              '배급사',
              '등급',
              '장르',
              '감독',
              '배우'
             ]

# %%
train.columns = new_colums
train.head()
# Out:
#                 순위  영화명                  개봉일         매출액 매출액 점유율 매출액증감 (전일대비)  \
# 0              NaN  NaN                  NaN         NaN     NaN          NaN
# 1  일별 박스오피스 검색 리스트  NaN                  NaN         NaN     NaN          NaN
# 2               순위  영화명                  개봉일        매출액      매출액        매출액증감
# 3              NaN  NaN                  NaN         NaN    점유율       (전일대비)
# 4                1   명량  2014-07-30 00:00:00  4892511700   0.595   -380933700
#
#   매출액증감율 (전일대비)        누적매출액     관객수 관객수증감 (전일대비)  \
# 0           NaN          NaN     NaN          NaN
# 1           NaN          NaN     NaN          NaN
# 2        매출액증감율       누적매출액     관객수         관객수증감
# 3       (전일대비)           NaN     NaN      (전일대비)
# 4          -0.1  61033902816  652776       -50111
#
#                          ...                           스크린수   상영횟수   대표국적  \
# 0                        ...                            NaN    NaN    NaN
# 1                        ...                            NaN    NaN    NaN
# 2                        ...                          스크린수   상영횟수   대표국적
# 3                        ...                            NaN    NaN    NaN
# 4                        ...                           1239   6776     한국
#
#     국적        제작사        배급사        등급     장르   감독  \
# 0  NaN        NaN        NaN       NaN    NaN  NaN
# 1  NaN        NaN        NaN       NaN    NaN  NaN
# 2  국적        제작사        배급사        등급     장르   감독
# 3  NaN        NaN        NaN       NaN    NaN  NaN
# 4   한국  (주)빅스톤픽쳐스  씨제이이앤엠(주)  15세이상관람가  사극,액션  김한민
#
#                                                   배우
# 0                                                NaN
# 1                                                NaN
# 2                                                배우
# 3                                                NaN
# 4  최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,김태훈,이승준,오타니 료헤이,...
#
# [5 rows x 22 columns]

# %%
train = train.dropna(how='all')
train
# Out:
#                   순위                         영화명                  개봉일  \
# 1    일별 박스오피스 검색 리스트                         NaN                  NaN
# 2                 순위                         영화명                  개봉일
# 3                NaN                         NaN                  NaN
# 4                  1                          명량  2014-07-30 00:00:00
# 5                  2                해적: 바다로 간 산적  2014-08-06 00:00:00
# 6                  3                  드래곤 길들이기 2  2014-07-23 00:00:00
# 7                  4                 가디언즈 오브 갤럭시  2014-07-31 00:00:00
# 8                  5           명탐정 코난 : 이차원의 저격수  2014-08-06 00:00:00
# 9                  6                  군도: 민란의 시대  2014-07-23 00:00:00
# 10                 7                        허큘리스  2014-08-06 00:00:00
# 11                 8               마담 프루스트의 비밀정원  2014-07-24 00:00:00
# 12                 9                          터키  2014-07-31 00:00:00
# 13                10  극장판 뛰뛰빵빵 구조대 미션: 둥둥이를 구하라!  2014-08-07 00:00:00
# 14                11                      비긴 어게인  2014-08-13 00:00:00
# 15                12                      유아 넥스트  2014-08-07 00:00:00
# 16                13                비행기 2: 소방구조대  2014-08-13 00:00:00
# 17                14                    삼총사 2014  2014-08-07 00:00:00
# 18                15                        동경가족  2014-07-31 00:00:00
# 19                16                       어떤 만남  2014-07-31 00:00:00
# 20                17                   모스트 원티드 맨  2014-08-07 00:00:00
# 21                18                       터널 3D  2014-08-20 00:00:00
# 22                19                           떡  2014-08-06 00:00:00
# 23                20                   빙봉협: 중생지문  2014-08-06 00:00:00
# 24                21                      프란시스 하  2014-07-17 00:00:00
# 25                22                    그 사람 추기경  2014-08-06 00:00:00
# 26                23                이십세기폭스코리아(주)                  NaN
# 27                24                혹성탈출: 반격의 서막  2014-07-10 00:00:00
# 28                25                 매직 인 더 문라이트  2014-08-20 00:00:00
# 29                26                          그녀  2014-05-22 00:00:00
# 30                27            뜨거운 양철 지붕 위의 고양이                  NaN
# ..               ...                         ...                  ...
# 493               42                       산타바바라  2014-07-16 00:00:00
# 494               43                  초급 이태리어 강습                  NaN
# 495               44                        피해자들  2014-07-31 00:00:00
# 496               45           커피 한잔이 섹스에 미치는 영향  2014-06-26 00:00:00
# 497               46                      쇼 미 러브                  NaN
# 498               46                   님포매니악 볼륨1  2014-06-18 00:00:00
# 499               46    랄프 스테드먼 스토리: 이상한 나라의 친구들  2014-07-10 00:00:00
# 500               49                      살인의 추억  2003-04-25 00:00:00
# 501               49                   파라노말 액티비티  2010-01-13 00:00:00
# 502               51                     미션 임파서블  1996-06-15 00:00:00
# 503               52                      마음의 고향                  NaN
# 504               53                        우리가족  2014-07-24 00:00:00
# 505               54                        베르테르  2014-07-12 00:00:00
# 506               55                         블랙딜  2014-07-03 00:00:00
# 507               56                      끝까지 간다  2014-05-29 00:00:00
# 508               57                  짓: 무삭제 감독판                  NaN
# 509               58                   머나먼 세상속으로  2014-07-31 00:00:00
# 510               58                  자, 이제 댄스타임  2014-06-26 00:00:00
# 511               58                     천번의 굿나잇  2014-07-03 00:00:00
# 512               61                         한공주  2014-04-17 00:00:00
# 513               61                         와즈다  2014-06-19 00:00:00
# 514               63                          경주  2014-06-12 00:00:00
# 515               63                     카토 프로젝트  2014-04-17 00:00:00
# 516               63                   울프 앳 더 도어  2014-07-10 00:00:00
# 517               63                   천하무적 키코리키  2014-07-17 00:00:00
# 518               67                     언더 더 스킨  2014-07-17 00:00:00
# 519               67                       카프리치오  2014-07-05 00:00:00
# 520               67            정동진독립영화제2013 섹션5                  NaN
# 521               67                      원나잇 온리  2014-07-03 00:00:00
# 522               합계                         NaN                  NaN
#
#              매출액 매출액 점유율 매출액증감 (전일대비) 매출액증감율 (전일대비)         누적매출액      관객수  \
# 1            NaN     NaN          NaN           NaN           NaN      NaN
# 2           매출액      매출액        매출액증감        매출액증감율        누적매출액      관객수
# 3            NaN    점유율       (전일대비)        (전일대비)            NaN      NaN
# 4     4892511700   0.595   -380933700          -0.1   61033902816   652776
# 5     1890503200    0.23   -130889400          -0.1    4137374300   254862
# 6      437352300   0.053    -27892900          -0.1   19775433889    58182
# 7      347508400   0.042    -11947100             0    7187518884    39837
# 8      262921800   0.032    103795200           0.7     433027400    38912
# 9      117147900   0.014    -22492000          -0.2   36269954124    15940
# 10      84582000    0.01     -2266400             0     181126400    11522
# 11      28236100   0.003     -1124700             0     493871942     3702
# 12      21254400   0.003    -11883800          -0.4     665969600     3231
# 13      18220700   0.002     15047900           4.7      31529500     2671
# 14      17206000   0.002    -17802000          -0.5      62323000     2285
# 15      14337400   0.002      6201400           0.8      31609400     1822
# 16      13568000   0.002      9498000           2.3      17638000     1696
# 17       5152000   0.001      5152000             1       5152000     1315
# 18       8967600   0.001       738600           0.1     103427300     1247
# 19       7956400   0.001     -1846000          -0.2     125821500     1089
# 20       7452900   0.001      6848400          11.3      13461400      971
# 21       9472000   0.001      9472000             1       9472000      902
# 22       3994000       0      3954000          98.9       4034000      841
# 23       3959000       0      3919000            98       3999000      835
# 24       5113100   0.001     -3836400          -0.4     488738800      686
# 25       3740500       0      3382200           9.4      38487800      548
# 26        978000       0      -340000          -0.3       3807000      489
# 27       1967000       0      -908000          -0.3   31497944295      329
# 28       2608000       0      2608000             1       2608000      326
# 29       1771000       0      -338500          -0.2    2828259400      235
# 30        437000       0       437000             1       9985000      217
# ..           ...     ...          ...           ...           ...      ...
# 493       313000       0      -120000          -0.3     120034000       45
# 494       178000       0       178000             1        178000       35
# 495       186000       0        10000           0.1       2288000       31
# 496       175000       0        88000             1      25468000       28
# 497       128000       0       128000             1        128000       26
# 498       252000       0       -23000          -0.1     475166883       26
# 499       131000       0        42000           0.5      29831800       26
# 500       122997       0       122997             1        448497       24
# 501       122997       0       122997             1    3209614497       24
# 502       136000       0       136000             1        331000       21
# 503        92000       0        92000             1         92000       19
# 504       108000       0      -357000          -0.8       1870000       18
# 505       310000       0       212500           2.2      15126000       17
# 506        94000       0        14000           0.2      58717200       15
# 507        66000       0        49000           2.9   27002629900       11
# 508        40000       0        40000             1         40000       10
# 509        41000       0       -87000          -0.7       2825000        7
# 510        49000       0        49000             1       7853500        7
# 511        56000       0      -322000          -0.9      73322000        7
# 512        29000       0        29000             1    1784429300        6
# 513        48000       0        16000           0.5      78503200        6
# 514        11000       0       -48000          -0.8     468281000        2
# 515         4000       0            0             0       1323000        2
# 516        14000       0        14000             1       3149000        2
# 517        12000       0        12000             1     149187900        2
# 518         7000       0         7000             1      13994000        1
# 519        30000       0      -190500          -0.9      10319500        1
# 520         4000       0         4000             1          4000        1
# 521         7000       0      -136000            -1      21461300        1
# 522  10807003325     NaN          NaN           NaN  219275618399  1351842
#
#     관객수증감 (전일대비)                        ...                           스크린수  \
# 1            NaN                        ...                            NaN
# 2          관객수증감                        ...                          스크린수
# 3        (전일대비)                         ...                            NaN
# 4         -50111                        ...                           1239
# 5         -18583                        ...                            795
# 6          -3510                        ...                            423
# 7          -1650                        ...                            344
# 8          15264                        ...                            261
# 9          -3066                        ...                            233
# 10          -187                        ...                            278
# 11          -185                        ...                             46
# 12         -1691                        ...                             54
# 13          2219                        ...                             87
# 14         -2091                        ...                             11
# 15           805                        ...                             78
# 16          1289                        ...                              6
# 17          1315                        ...                             21
# 18            97                        ...                             35
# 19          -218                        ...                             29
# 20           902                        ...                             26
# 21           902                        ...                              2
# 22           831                        ...                             21
# 23           825                        ...                             20
# 24          -515                        ...                             33
# 25           498                        ...                             43
# 26          -163                        ...                              1
# 27           -58                        ...                              6
# 28           326                        ...                              1
# 29           -50                        ...                              8
# 30           217                        ...                              1
# ..           ...                        ...                            ...
# 493          -16                        ...                              3
# 494           35                        ...                              1
# 495            1                        ...                              4
# 496           17                        ...                              1
# 497           26                        ...                              1
# 498           -5                        ...                              3
# 499            8                        ...                              2
# 500           24                        ...                              1
# 501           24                        ...                              1
# 502           21                        ...                              1
# 503           19                        ...                              1
# 504          -57                        ...                              6
# 505           13                        ...                              1
# 506            5                        ...                              2
# 507            8                        ...                              1
# 508           10                        ...                              1
# 509          -15                        ...                              2
# 510            7                        ...                              1
# 511          -37                        ...                              1
# 512            6                        ...                              1
# 513            2                        ...                              1
# 514           -7                        ...                              1
# 515            0                        ...                              1
# 516            2                        ...                              1
# 517            2                        ...                              1
# 518            1                        ...                              1
# 519           -8                        ...                              1
# 520            1                        ...                              1
# 521          -23                        ...                              1
# 522          NaN                        ...                           3854
#
#       상영횟수   대표국적                 국적  \
# 1      NaN    NaN                NaN
# 2    상영횟수   대표국적                 국적
# 3      NaN    NaN                NaN
# 4     6776     한국                 한국
# 5     3932     한국                 한국
# 6     1016     미국                 미국
# 7      844     미국                 미국
# 8      514     일본                 일본
# 9      495     한국                 한국
# 10     692     미국                 미국
# 11     119    프랑스                프랑스
# 12      68     미국                 미국
# 13     127     한국                 한국
# 14      11     미국                 미국
# 15     118     미국                 미국
# 16       6     미국                 미국
# 17      21    러시아                러시아
# 18      50     일본                 일본
# 19      43    프랑스                프랑스
# 20      42     영국           영국,미국,독일
# 21       4     한국                 한국
# 22      21     한국                 한국
# 23      20     홍콩                 홍콩
# 24      40     미국                 미국
# 25      54     한국                 한국
# 26       4     미국                 미국
# 27       8     미국                 미국
# 28       1     미국                 미국
# 29      10     미국                 미국
# 30       4     미국                 미국
# ..     ...    ...                ...
# 493      7     한국                 한국
# 494      1    덴마크                덴마크
# 495      5     한국                 한국
# 496      1     미국                 미국
# 497      1    스웨덴                스웨덴
# 498      3    덴마크  덴마크,독일,프랑스,벨기에,영국
# 499      2     영국              영국,미국
# 500      1     한국                 한국
# 501      1     미국                 미국
# 502      1     미국                 미국
# 503      1    NaN                NaN
# 504      9     한국                 한국
# 505      1     미국                 미국
# 506      3     한국                 한국
# 507      1     한국                 한국
# 508      1     한국                 한국
# 509      3    프랑스        프랑스,벨기에,캐나다
# 510      1     한국                 한국
# 511      1   노르웨이      노르웨이,아일랜드,스웨덴
# 512      1     한국                 한국
# 513      1     기타              기타,독일
# 514      1     한국                 한국
# 515      2     한국                 한국
# 516      1    브라질                브라질
# 517      1    러시아                러시아
# 518      1     영국                 영국
# 519      1     독일                 독일
# 520      1     한국                 한국
# 521      1     한국                 한국
# 522  15093    NaN                NaN
#
#                                                제작사                       배급사  \
# 1                                              NaN                       NaN
# 2                                             제작사                       배급사
# 3                                              NaN                       NaN
# 4                                        (주)빅스톤픽쳐스                 씨제이이앤엠(주)
# 5                                       (주)하리마오픽쳐스             롯데쇼핑㈜롯데엔터테인먼트
# 6                                       드림웍스 애니메이션                 씨제이이앤엠(주)
# 7                                          마블 스튜디오  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)
# 8                                       TMS 엔터테인먼트                 씨제이이앤엠(주)
# 9                                 (주)영화사 월광,(주)쇼박스                    (주)쇼박스
# 10   Paramount Pictures, Metro-Goldwyn-Mayer (MGM)             워너브러더스 코리아(주)
# 11                                         클로드 오자르                        찬란
# 12                                             NaN             롯데쇼핑㈜롯데엔터테인먼트
# 13                   (주)빅스크리에이티브,(주)디씨지플러스,차이나필름그룹               메가박스(주)플러스엠
# 14   시카 픽처스, 엑스큐스 미디어, 라이키 스토리, 아파 프로덕션, 블랙 라벨 미디어                   판씨네마(주)
# 15              HanWay Films, Snoot Entertainment                  ㈜영화사 백두대간
# 16                           디즈니툰 스튜디오, 월트 디즈니 픽처스  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)
# 17                                             NaN                 (주)소나무픽쳐스
# 18                                             쇼치쿠                        오드
# 19                                             NaN              (주)티캐스트콘텐츠허브
# 20                                             NaN      (주)드림웨스트픽쳐스,(주)인벤트스톤
# 21                    (주)필마픽쳐스 ,(주)씨제이에스지 마당엔터테인먼트               (주)박수엔터테인먼트
# 22                                        (주)케이알씨지                  (주)케이알씨지
# 23                                             NaN                (주)팝엔터테인먼트
# 24                                             NaN                그린나래미디어(주)
# 25                                            평화방송               (주)씨타마운틴픽쳐스
# 26                                   이십세기폭스필름코퍼레이션              이십세기폭스코리아(주)
# 27                                    이십세기폭스코리아(주)              이십세기폭스코리아(주)
# 28                                             NaN                  (주)인벤트스톤
# 29                                             NaN       유니버설픽쳐스인터내셔널 코리아(유)
# 30                                             NaN                       NaN
# ..                                             ...                       ...
# 493                                      (주)영화사 조제             (주)나이너스엔터테인먼트
# 494                                            NaN                       NaN
# 495                                     (주)노시스에프앤디               골든타이드픽처스(주)
# 496                                            NaN                 ㈜영화사 백두대간
# 497                                            NaN                       NaN
# 498                                            NaN                  CGV아트하우스
# 499                                            NaN                    ㈜인디스토리
# 500                                        (주)싸이더스                 씨제이엔터테인먼트
# 501                                     브름하우스 프로덕션       (주)넥스트엔터테인먼트월드(NEW)
# 502                                      파라마운트 픽쳐스                       NaN
# 503                                            NaN                       NaN
# 504                                            NaN               (주)씨타마운틴픽쳐스
# 505                                            NaN                 (주)인스터피씨엠
# 506                                       (주)인디플러그                  (주)인디플러그
# 507                             (주)에이디사공육,(주)다세포클럽                    (주)쇼박스
# 508                                           ㈜리필름                (주)팝엔터테인먼트
# 509                                            NaN               (주)씨타마운틴픽쳐스
# 510                                            NaN             주식회사 키노엔터테인먼트
# 511                                            NaN             (주)마인스 엔터테인먼트
# 512                                      리 공동체 영화사                  CGV아트하우스
# 513                                            NaN                 (주)프레인글로벌
# 514                                   (주)인벤트스톤,률필름                  (주)인벤트스톤
# 515                                    (주)씨타마운틴픽쳐스               (주)씨타마운틴픽쳐스
# 516                                            NaN                 ㈜영화사 백두대간
# 517                                            NaN                와이드 릴리즈(주)
# 518                                            NaN               씨네그루(주)다우기술
# 519                                            NaN                (주)쓰리캣프로덕션
# 520                                            NaN                       NaN
# 521                                     (주)레인보우팩토리                (주)레인보우팩토리
# 522                                            NaN                       NaN
#
#             등급               장르               감독  \
# 1          NaN              NaN              NaN
# 2          등급               장르               감독
# 3          NaN              NaN              NaN
# 4     15세이상관람가            사극,액션              김한민
# 5     12세이상관람가             어드벤처              이석훈
# 6        전체관람가    애니메이션,액션,어드벤처          딘 데블로이스
# 7     12세이상관람가       액션,어드벤처,SF            제임스 건
# 8     12세이상관람가   애니메이션,스릴러,어드벤처           시즈노 코분
# 9     15세이상관람가            사극,액션              윤종빈
# 10    15세이상관람가          액션,어드벤처           브렛 래트너
# 11       전체관람가              드라마            실뱅 쇼메
# 12       전체관람가        애니메이션,코미디          지미 헤이워드
# 13       전체관람가            애니메이션              방형우
# 14    15세이상관람가           멜로/로맨스             존 카니
# 15     청소년관람불가        공포(호러),액션           아담 윈가드
# 16       전체관람가   애니메이션,어드벤처,코미디         로버츠 개너웨이
# 17    15세이상관람가             어드벤처         세르게이 지노프
# 18       전체관람가           가족,드라마           야마다 요지
# 19     청소년관람불가           멜로/로맨스         리사 아주엘로스
# 20     청소년관람불가          스릴러,드라마           안톤 코르빈
# 21    15세이상관람가       공포(호러),스릴러              박규택
# 22     청소년관람불가       멜로/로맨스,드라마              이영인
# 23    15세이상관람가       액션,판타지,코미디              나영창
# 24    15세이상관람가       코미디,멜로/로맨스           노아 바움백
# 25       전체관람가            다큐멘터리              전성우
# 26         NaN          드라마,뮤지컬          오토 프레밍거
# 27    12세이상관람가    액션,드라마,SF,스릴러            맷 리브스
# 28    12세이상관람가   코미디,드라마,멜로/로맨스            우디 앨런
# 29     청소년관람불가       드라마,멜로/로맨스          스파이크 존즈
# 30         NaN              드라마          리차드 브룩스
# ..         ...              ...              ...
# 493   15세이상관람가       멜로/로맨스,드라마              조성규
# 494        NaN   코미디,드라마,멜로/로맨스            론 쉐르픽
# 495    청소년관람불가         미스터리,스릴러              노진수
# 496    청소년관람불가              드라마          스테이시 패숀
# 497        NaN           멜로/로맨스          루카스 무디슨
# 498    청소년관람불가              드라마         라스 폰 트리에
# 499   12세이상관람가            다큐멘터리             찰리 폴
# 500     15세관람가              스릴러              봉준호
# 501   12세이상관람가  공포(호러),미스터리,스릴러            오렌 펠리
# 502  고등학생이상관람가     액션,어드벤처,미스터리        브라이언 드 팔마
# 503        NaN              NaN              NaN
# 504      전체관람가            다큐멘터리              김도현
# 505      전체관람가               공연           리처드 이어
# 506   12세이상관람가            다큐멘터리              이훈규
# 507   15세이상관람가        액션,스릴러,범죄              김성훈
# 508    청소년관람불가       멜로/로맨스,드라마              한종훈
# 509      전체관람가            애니메이션       장 크리스토프 드상
# 510   15세이상관람가            다큐멘터리              조세영
# 511   12세이상관람가              드라마            에릭 포페
# 512    청소년관람불가              드라마              이수진
# 513      전체관람가              드라마        하이파 알-만수르
# 514   15세이상관람가   드라마,코미디,멜로/로맨스               장률
# 515      전체관람가            다큐멘터리              김정욱
# 516    청소년관람불가              드라마        페르난도 코임브라
# 517      전체관람가       애니메이션,어드벤처         데니스 체르노프
# 518    청소년관람불가           SF,드라마         조나단 글레이저
# 519      전체관람가               공연     마르코 아르투로 마렐리
# 520        NaN               기타  유혜지,이미랑,송윤희,이진우
# 521    청소년관람불가               기타             김조광수
# 522        NaN              NaN              NaN
#
#                                                     배우
# 1                                                  NaN
# 2                                                  배우
# 3                                                  NaN
# 4    최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,김태훈,이승준,오타니 료헤이,...
# 5    김남길,손예진,유해진,이경영,오달수,김태우,박철민,신정근,김원해,조달환,조희봉,정성...
# 6                      제이 바루첼,제라드 버틀러,케이트 블란쳇,아메리카 페레라
# 7                   크리스 프랫,조 샐다나,데이브 바티스타,빈 디젤,브래들리 쿠퍼
# 8                                    타카야마 미나미, 히다카 노리코
# 9    하정우,강동원,최귀화,이성민,조진웅,마동석,윤지혜,정만식,김성균,김재영,주진모,이경...
# 10             드웨인 존슨,존 허트,이안 맥쉐인,조셉 파인즈,이리나 샤크,바바라 팔빈
# 11                                         귀욤 고익스,앤 르니
# 12                                        우디 해럴슨,오웬 윌슨
# 13                                     양정화,안영미,김서영,이용신
# 14      키이라 나이틀리,마크 러팔로,애덤 리바인,헤일리 스테인펠드,제임스 코든,캐서린 키너
# 15                             샤니 빈슨,AJ 보웬,조 스완버그,롭 모란
# 16                                   데인 쿡,에드 해리스,줄리 보웬
# 17                                        파벨 바샤크,유리 추신
# 18   하시즈메 이사오,요시유키 카즈코,츠마부키 사토시,아오이 유우,니시무라 마사히코,나츠...
# 19                                     소피 마르소,프랑수아 클뤼제
# 20                   필립 세이모어 호프만,레이첼 맥아담스,윌렘 데포,로빈 라이트
# 21   정유미,연우진,송재림,정시연,이태현,박지원,서종민,전수아,전우재,양영택,유세문,정원...
# 22                                               추선,김원
# 23                                         견자단,황성의,임달화
# 24                        그레타 거윅,믹키 섬너,그레이스 검머,아담 드라이버
# 25                                             김수환,김영균
# 26                              해리 벨라폰테,도로시 댄드리지,펄 베일리
# 27                                앤디 서키스,게리 올드만,제이슨 클락
# 28                                         콜린 퍼스,엠마 스톤
# 29                       호아킨 피닉스,스칼렛 요한슨,에이미 아담스,루니 마라
# 30                               엘리자베스 테일러,폴 뉴먼,벌 아이비스
# ..                                                 ...
# 493  이상윤,윤진서,이솜,서범석,신동미,정미라,정여은,강유현,차수민,이덕화,이석현,이선영...
# 494                             안데르스 W. 베르텔센,아네테 스토벨바엑
# 495  류태준,장은아,연송하,송찬호,이가영,이상훈,이승현,이원기,이은주,김주애,김진휘,김진...
# 496                                      매기 시프,로빈 웨이거트
# 497                        알렉산드라 달스트롬,레베카 릴예베르그,에리카 칼슨
# 498  샤를로뜨 갱스부르,스텔란 스카스가드,스테이시 마틴,샤이아 라보프,크리스찬 슬레이터,...
# 499                                       랄프 스테드먼,조니 뎁
# 500  송강호,김상경,김뢰하,정인선,한충환,김효성,이강산,김민철,최현기,심성보,김희진,한성...
# 501                           케이티 피더스턴,미카 슬로앳,마크 프레드릭스
# 502                          톰 크루즈,존 보이트,엠마누엘 베아르,장 르노
# 503                                                NaN
# 504  김태훈,박은영,강민석,박진우,이희정,염하룡,이성태,이승환,이원영,이은정,김민석,김소...
# 505                                                NaN
# 506                                                정태춘
# 507  이선균,조진웅,신정근,정만식,신동미,김동영,박보검,박진성,정하철,윤종현,이승준,이준...
# 508                                            서태화,서은아
# 509                                장 르노,로란트 도이취,이자벨 까레
# 510                                        박지혜,송삼동,지주현
# 511                                줄리엣 비노쉬,니콜라이 코스터 왈도
# 512  천우희,우혜진,정인선,김소영,강대현,백지원,임동석,장순호,전준영,정한빈,이상헌,이슬...
# 513                                            와드 모하메드
# 514  박해일,신민아,김태훈,신소율,이춘연,이학민,박재웅,박재희,박진홍,임상묵,임진욱,신민...
# 515                    강민지,박정원,이승희,이윤희,이은지,이준영,김효정,박수정
# 516                             린드라 릴,밀헴 코타즈,파비울라 나쉬멘토
# 517                                                NaN
# 518                                     스칼렛 요한슨,폴 프래니건
# 519                                             르네 플레밍
# 520                                                NaN
# 521                        유민규,박수진,장유상,정원조,김대준,김민기,조복래
# 522                                                NaN
#
# [510 rows x 22 columns]

# %%
train.dtypes
# Out:
# 순위               object
# 영화명              object
# 개봉일              object
# 매출액              object
# 매출액 점유율          object
# 매출액증감 (전일대비)     object
# 매출액증감율 (전일대비)    object
# 누적매출액            object
# 관객수              object
# 관객수증감 (전일대비)     object
# 관객수증감율 (전일대비)    object
# 누적관객수            object
# 스크린수             object
# 상영횟수             object
# 대표국적             object
# 국적               object
# 제작사              object
# 배급사              object
# 등급               object
# 장르               object
# 감독               object
# 배우               object
# dtype: object

# %% [markdown]
# ## Test - Split and extract dates

# %%
# train['순위'] = train['순위'].astype(str)

# %%
# train['순위'] = train['순위'].apply(lambda x: x.split(' '))
# train.loc[train['순위'].str[0]=='2014년']

# %% [markdown]
# ## Insert Dates column

# %%
train.loc[train['순위']=='합계'].index.values
# Out:
# array([ 69, 151, 234, 304, 373, 445, 522], dtype=int64)

# %%
train.insert(0, '날짜', '2014년')
train.head(3)
# Out:
#       날짜               순위  영화명  개봉일   매출액 매출액 점유율 매출액증감 (전일대비) 매출액증감율 (전일대비)  \
# 1  2014년  일별 박스오피스 검색 리스트  NaN  NaN   NaN     NaN          NaN           NaN
# 2  2014년               순위  영화명  개봉일  매출액      매출액        매출액증감        매출액증감율
# 3  2014년              NaN  NaN  NaN   NaN    점유율       (전일대비)        (전일대비)
#
#     누적매출액   관객수 ...    스크린수   상영횟수   대표국적   국적   제작사   배급사   등급   장르   감독   배우
# 1     NaN   NaN ...     NaN    NaN    NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 2  누적매출액   관객수  ...   스크린수   상영횟수   대표국적   국적   제작사   배급사   등급   장르   감독   배우
# 3     NaN   NaN ...     NaN    NaN    NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 23 columns]

# %%
train.loc[0:69, '날짜'] = '2014-08-07-목'
train.loc[70:151, '날짜'] = '2014-08-06-수'
train.loc[152:234, '날짜'] = '2014-08-05-화'
train.loc[235:304, '날짜'] = '2014-08-04-월'
train.loc[305:373, '날짜'] = '2014-08-03-일'
train.loc[374:445, '날짜'] = '2014-08-02-토'
train.loc[446:522, '날짜'] = '2014-08-01-금'

train.head(3)
# Out:
#              날짜               순위  영화명  개봉일   매출액 매출액 점유율 매출액증감 (전일대비)  \
# 1  2014-08-07-목  일별 박스오피스 검색 리스트  NaN  NaN   NaN     NaN          NaN
# 2  2014-08-07-목               순위  영화명  개봉일  매출액      매출액        매출액증감
# 3  2014-08-07-목              NaN  NaN  NaN   NaN    점유율       (전일대비)
#
#   매출액증감율 (전일대비)   누적매출액   관객수 ...    스크린수   상영횟수   대표국적   국적   제작사   배급사   등급  \
# 1           NaN     NaN   NaN ...     NaN    NaN    NaN  NaN   NaN   NaN  NaN
# 2        매출액증감율  누적매출액   관객수  ...   스크린수   상영횟수   대표국적   국적   제작사   배급사   등급
# 3       (전일대비)      NaN   NaN ...     NaN    NaN    NaN  NaN   NaN   NaN  NaN
#
#     장르   감독   배우
# 1  NaN  NaN  NaN
# 2  장르   감독   배우
# 3  NaN  NaN  NaN
#
# [3 rows x 23 columns]

# %%
train.loc[train['순위']=='일별 박스오피스 검색 리스트'].index.values[0]
# Out:
# 1

# %%
# train.drop(train['순위']=='순위')
# train.drop(train['순위']=='합계')
train = train.drop(train.loc[train['순위']=='일별 박스오피스 검색 리스트'].index.values[0:])
train = train.drop(train.loc[train['순위']=='순위'].index.values[0:])
train = train.drop(train.loc[train['순위']=='합계'].index.values[0:])
train = train.drop(train.loc[train['매출액 점유율']=='점유율 '].index.values[0:])

train.head(3)
# Out:
#              날짜 순위           영화명                  개봉일         매출액 매출액 점유율  \
# 4  2014-08-07-목  1            명량  2014-07-30 00:00:00  4892511700   0.595
# 5  2014-08-07-목  2  해적: 바다로 간 산적  2014-08-06 00:00:00  1890503200    0.23
# 6  2014-08-07-목  3    드래곤 길들이기 2  2014-07-23 00:00:00   437352300   0.053
#
#   매출액증감 (전일대비) 매출액증감율 (전일대비)        누적매출액     관객수  \
# 4   -380933700          -0.1  61033902816  652776
# 5   -130889400          -0.1   4137374300  254862
# 6    -27892900          -0.1  19775433889   58182
#
#                          ...                          스크린수  상영횟수 대표국적  국적  \
# 4                        ...                          1239  6776   한국  한국
# 5                        ...                           795  3932   한국  한국
# 6                        ...                           423  1016   미국  미국
#
#           제작사            배급사        등급             장르       감독  \
# 4   (주)빅스톤픽쳐스      씨제이이앤엠(주)  15세이상관람가          사극,액션      김한민
# 5  (주)하리마오픽쳐스  롯데쇼핑㈜롯데엔터테인먼트  12세이상관람가           어드벤처      이석훈
# 6  드림웍스 애니메이션      씨제이이앤엠(주)     전체관람가  애니메이션,액션,어드벤처  딘 데블로이스
#
#                                                   배우
# 4  최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,김태훈,이승준,오타니 료헤이,...
# 5  김남길,손예진,유해진,이경영,오달수,김태우,박철민,신정근,김원해,조달환,조희봉,정성...
# 6                    제이 바루첼,제라드 버틀러,케이트 블란쳇,아메리카 페레라
#
# [3 rows x 23 columns]

# %%
# train[0:(train.loc[train['순위'].str[0]=='합계'].index.values[0])]
# train.dropna(subset='순위')

# %%
# train['날짜'] = train[0:(train.loc[train['순위'].str[0]=='합계'].index.values[0])]

# %%
# train['순위'] = train_df['순위'].apply(lambda x: clean_file(x))

# %% [markdown]
# ## Output

# %%
train.to_csv(new_filename)

# %% [markdown]
# ---
# # Reset index  - junwoo -

# %%
#train = train.reset_index() # 전체 엑셀파일 데이터 다 모으고 하면됌
#train = train.drop('index',axis=1)

# %% [markdown]
# # Find NaN data and delete row

# %%
train.info() # 보니깐 482개중에 6개가 중간에 끼인 날짜정보칸임 476개만 진짜
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 24 columns):
# level_0          482 non-null int64
# 날짜               482 non-null object
# 순위               482 non-null object
# 영화명              476 non-null object
# 개봉일              428 non-null object
# 매출액              476 non-null object
# 매출액 점유율          476 non-null object
# 매출액증감 (전일대비)     476 non-null object
# 매출액증감율 (전일대비)    476 non-null object
# 누적매출액            476 non-null object
# 관객수              476 non-null object
# 관객수증감 (전일대비)     476 non-null object
# 관객수증감율 (전일대비)    476 non-null object
# 누적관객수            476 non-null object
# 스크린수             476 non-null object
# 상영횟수             476 non-null object
# 대표국적             473 non-null object
# 국적               473 non-null object
# 제작사              167 non-null object
# 배급사              408 non-null object
# 등급               437 non-null object
# 장르               473 non-null object
# 감독               463 non-null object
# 배우               425 non-null object
# dtypes: int64(1), object(23)
# memory usage: 90.5+ KB

# %%
index=pd.isnull(train['영화명'])
for i in range(1,len(index)):
    if index[i]==True :
        print (i)
# Out:
# 65
# 141
# 218
# 282
# 345
# 411

# %%
train.ix[282]
# Out:
# level_0                       282
# 날짜                   2014-08-03-일
# 순위               2014년 08월 03일(일)
# 영화명                           NaN
# 개봉일                           NaN
# 매출액                           NaN
# 매출액 점유율                       NaN
# 매출액증감 (전일대비)                  NaN
# 매출액증감율 (전일대비)                 NaN
# 누적매출액                         NaN
# 관객수                           NaN
# 관객수증감 (전일대비)                  NaN
# 관객수증감율 (전일대비)                 NaN
# 누적관객수                         NaN
# 스크린수                          NaN
# 상영횟수                          NaN
# 대표국적                          NaN
# 국적                            NaN
# 제작사                           NaN
# 배급사                           NaN
# 등급                            NaN
# 장르                            NaN
# 감독                            NaN
# 배우                            NaN
# Name: 282, dtype: object

# %%
train = train.dropna(thresh=10) # NAN값이 10개 이상인 row 삭제
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 476 entries, 0 to 481
# Data columns (total 24 columns):
# level_0          476 non-null int64
# 날짜               476 non-null object
# 순위               476 non-null object
# 영화명              476 non-null object
# 개봉일              428 non-null object
# 매출액              476 non-null object
# 매출액 점유율          476 non-null object
# 매출액증감 (전일대비)     476 non-null object
# 매출액증감율 (전일대비)    476 non-null object
# 누적매출액            476 non-null object
# 관객수              476 non-null object
# 관객수증감 (전일대비)     476 non-null object
# 관객수증감율 (전일대비)    476 non-null object
# 누적관객수            476 non-null object
# 스크린수             476 non-null object
# 상영횟수             476 non-null object
# 대표국적             473 non-null object
# 국적               473 non-null object
# 제작사              167 non-null object
# 배급사              408 non-null object
# 등급               437 non-null object
# 장르               473 non-null object
# 감독               463 non-null object
# 배우               425 non-null object
# dtypes: int64(1), object(23)
# memory usage: 93.0+ KB

# %% [markdown]
# # NaN Data
#  - 개봉일 - 전부 합치고 가장 처음등장한 날짜를 개봉일로 채워주면 될듯
#  - 대표국적 -
#  - 국적 -
#  - 제작사 -
#  - 배급사 -
#  - 등급 -
#  - 장르 -
#  - 감독 -
#  - 배우 - (나머진 고민좀 해봐야할듯)
